# %% [markdown]
# # Energy Visualization Lab — exploration\nExploration only; deliverable lives in `src/`.

# %%
import sys\nfrom pathlib import Path\nsys.path.insert(0, str(Path('..') / 'src'))\nfrom energyviz.data import load_sample\nload_sample().head()
